# %%
import pandas as pd

# %%
all_dataframes = pd.read_html('https://sitereport.netcraft.com/?url=https%3A%2F%2Fespana2000.es')

# %%
len(all_dataframes)
# Out:
# 5

# %%
all_dataframes[0]
# Out:
#              0            1
# 0   Site title          NaN
# 1    Site rank  Not Present
# 2  Description          NaN

# %%
all_dataframes[1]
# Out:
#                       0                                                  1
# 0       Date first seen                                           May 2020
# 1  Netcraft Risk Rating  1/10 .mini-progress-bar {  display:inline-bloc...
# 2      Primary language                                                NaN

# %%
all_dataframes[2]
# Out:
#                          0                            1
# 0                     Site        https://espana2000.es
# 1           Netblock Owner            Cloud Builders SA
# 2          Hosting company                Interdominios
# 3          Hosting country                           ES
# 4             IPv4 address  89.248.106.181 (VirusTotal)
# 5  IPv4 autonomous systems                      AS48348
# 6             IPv6 address                  Not Present
# 7  IPv6 autonomous systems                  Not Present
# 8              Reverse DNS            host.virtualis.es

# %%
all_dataframes[3]
# Out:
#                          0                       1
# 0                   Domain           espana2000.es
# 1               Nameserver        ns.espana2000.es
# 2         Domain registrar                 unknown
# 3  Nameserver organisation                 unknown
# 4             Organisation                 unknown
# 5                DNS admin  webmaster@virtualis.es
# 6         Top Level Domain             Spain (.es)
# 7  DNS Security Extensions                 unknown
# 8       Latest Performance       Performance Graph

# %%
all_dataframes[4]
# Out:
#                             IP range        Country  \
# 0                  ::ffff:0.0.0.0/96  United States
# 1     &rdsh; 89.0.0.0-89.255.255.255    Netherlands
# 2  &rdsh; 89.248.96.0-89.248.111.255          Spain
# 3              &rdsh; 89.248.106.181          Spain
#
#                         Name                          Description
# 0   IANA-IPV4-MAPPED-ADDRESS  Internet Assigned Numbers Authority
# 1                    89-RIPE     RIPE Network Coordination Centre
# 2  ES-CLOUDBUILDERS-20060704                    Cloud Builders SA
# 3  ES-CLOUDBUILDERS-20060704                    Cloud Builders SA

# %%
pd.read_clipboard()
# Out:
#              Assurance Domain validation
# 0          Common name     espana2000.es
# 1         Organisation       Not Present
# 2                State       Not Present
# 3              Country       Not Present
# 4  Organisational unit       Not Present

# %%
pd.read_clipboard()
# Out:
# Empty DataFrame
# Columns: [Subject, Alternative, Name, espana2000.es,, webmail.espana2000.es,, www.espana2000.es]
# Index: []

# %%
pd.read_clipboard()
# Out:
#                            Validity period  \
# 0                         Matches hostname
# 1                                   Server
# 2                     Public key algorithm
# 3                         Protocol version
# 4                        Public key length
# 5                        Certificate check
# 6                      Signature algorithm
# 7                            Serial number
# 8                                   Cipher
# 9                           Version number
# 10                 Perfect Forward Secrecy
# 11                Supported TLS Extensions
# 12  Application-Layer Protocol Negotiation
# 13               Next Protocol Negotiation
# 14                    Issuing organisation
# 15                      Issuer common name
# 16                             Issuer unit
# 17                         Issuer location
# 18                          Issuer country
# 19                            Issuer state
# 20            Certificate Revocation Lists
# ...

# %%
pd.read_clipboard()
# Out:
#                                          Source         Log Timestamp  \
# 0                                   Certificate      Google     Argon
# 1  KXm+8J45OSHwVnOfY6V35b5XfZxgCvj5TV0mXCVdx4Q=  2022-05-30  12:39:18
# 2                                   Certificate     Sectigo   Mammoth
# 3  b1N2rDHwMRnYmQCkURX/dxUcEdkCwQApBo2yCJo32RM=  2022-05-30  12:39:18
#
#   Signature  Verification
# 0      2022           NaN
# 1   Success           NaN
# 2      None           NaN
# 3   Success           NaN
